# %% [markdown]
# <a href="https://colab.research.google.com/github/Virpaljadeja/machine-learning/blob/master/ds_ml_matploatlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
x = [0,1,2,3,4]
y= [0,2,4,6,8]

plt.plot(x,y)
plt.title("First demo example") # given title to our ploat 
plt.xlabel("X axis ")
plt.ylabel("Y axis")
plt.savefig("Demo.png")
